# %% [markdown]
# # Project: Data Review
#
# Review simulation driving data before training behavior cloning models.

# %% [markdown]
# ## Goals
#
# - Load the driving log CSV.
# - Inspect available columns.
# - Visualize steering distribution.
# - Review sample simulator images.

# %% [markdown]
# ## Load Driving Log
#
# Use this section to load `data/processed/driving_log.csv` when simulation data is available.

# %% [markdown]
# ## Visualize Steering Distribution
#
# Plot steering values to check whether the dataset is balanced.

# %% [markdown]
# ## Review Sample Images
#
# Display simulator frames and compare them with logged steering labels.
